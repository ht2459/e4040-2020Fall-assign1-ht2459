new learning rate = 0.0007350918906249997
# 5000/49000 loss: 1.4801275316982572
# 10000/49000 loss: 1.4170032665204784
# 15000/49000 loss: 1.4556326419786465
# 20000/49000 loss: 1.5386087725327227
# 25000/49000 loss: 1.495893379946127
# 30000/49000 loss: 1.566166725037956
# 35000/49000 loss: 1.5023828789629246
# 40000/49000 loss: 1.4731793023760547
# 45000/49000 loss: 1.4886868257704078
# epoch 7: valid acc = 0.336, new learning rate = 0.0006983372960937497
# 5000/49000 loss: 1.389697193507679
# 10000/49000 loss: 1.4771246029894534
# 15000/49000 loss: 1.4602634398885248
# 20000/49000 loss: 1.4497113568519273
# 25000/49000 loss: 1.480343382691673
# 30000/49000 loss: 1.5022043414428252
# 35000/49000 loss: 1.4745820607888593
# 40000/49000 loss: 1.4818937617177967
# 45000/49000 loss: 1.442163646826102
# epoch 8: valid acc = 0.346, new learning rate = 0.0006634204312890621
# 5000/49000 loss: 1.4025136237621996
# 10000/49000 loss: 1.387702426036075
# 15000/49000 loss: 1.4543936436611185
# 20000/49000 loss: 1.4070002832863748
# 25000/49000 loss: 1.430804043957473
# 30000/49000 loss: 1.4045344542074696
# 35000/49000 loss: 1.4616870615190538
# 40000/49000 loss: 1.3426064985552888
# 45000/49000 loss: 1.4502293983823114
# epoch 9: valid acc = 0.343, new learning rate = 0.000630249409724609
# 5000/49000 loss: 1.408246242002764
# 10000/49000 loss: 1.3490563299758196
# 15000/49000 loss: 1.4075126407845602
# 20000/49000 loss: 1.4430084714712212
# 25000/49000 loss: 1.4838040001286363
# 30000/49000 loss: 1.4293757815037724
# 35000/49000 loss: 1.373357876896896
# 40000/49000 loss: 1.4360124833128933
# 45000/49000 loss: 1.4536123211680039
# epoch 10: valid acc = 0.343, new learning rate = 0.0005987369392383785
# test acc: 0.3546
# 0.3546

# %% [markdown]
# <p style='color:red'><strong>SOLUTION (enter a new cell below):</strong></p>

# %% [markdown]
# <p style='color:red'><strong>TODO</strong></p>

# %%
## plot training and validation accuracy of your best model

# %% [markdown]
# <p style='color:red'><strong>SOLUTION (enter a new cell below):</strong></p>

# %%
plt.plot(train_acc_hist, label="train accuracy")
plt.plot(val_acc_hist, label="validation accuracy")
plt.legend()
plt.show()

# %%
##  Visualize weights of the first layer

# %% [markdown]
# <p style='color:red'><strong>SOLUTION (enter a new cell below):</strong></p>

# %%
weights = model.layer1.params[0]
pics = weights.reshape(3, 32, 32, -1).transpose(3, 1, 2, 0)
# visualization
visualize_pics(pics)
# Out:
# num of feature vectors: 100

# %% [markdown]
# ### Save your best model in a dictionary

# %%
## Create "save_model" folder if it does not exist
save_dir = "./save_models/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

## Save your model
save_params = model.save_model()
with open("./save_models/best_model.pkl", "wb") as output_file:
    pickle.dump(save_params, output_file)

# %%
## Load your model - FYI
#with open("./save_models/best_model.pkl", "rb") as input_file:
#    load_params = pickle.load(input_file)
    
#model.update_model(load_params)

# %% [markdown]
# ## Part 3: Multilayer Network
#
# Complete the class **MLP** in **./utils/classifiers/network.py**. It should allow arbitrary settings for the number of hidden layers as well as the number of hidden neurons in each layer. **MLP** has a similar structure as a **TwoLayerNet** network.
#
# ```
# class MLP:
#     functions: __init__, loss, step, predict, check_accuracy
#     variables: layers
# ```

# %% [markdown]
# <span style="color:red"><strong>TODO</strong></span>: Complete the class **MLP** in **./utils/classifiers/mlp.py**

# %% [markdown]
# <span style="color:red"><strong>NOTE</strong></span>: Please do not change the code in the cell below, The cell below will run correctly if your code is right.

# %%
# THE FOLLOWING CODE IS JUST FOR CHECKING.     #
# NO NEED TO CHANGE IT.                        #

from utils.classifiers.mlp import MLP

## Use a sequence of layers to create a multiple layer neural network
## input->(affine->activation)-> ... ->(affine->activation)->(affine->softmax)->output
model = MLP(input_dim=3072, hidden_dims=[100, 100], num_classes=10, reg=0.1, weight_scale=1e-3)

num_epoch = 10
batch_size = 500
lr = 1e-2
verbose = False
train_acc_hist, val_acc_hist = train(model, X_train, y_train, X_val, y_val, 
                  num_epoch=num_epoch, batch_size=batch_size, learning_rate=lr, verbose=verbose)
test(model, X_test, y_test)
# Out:
# number of batches for training: 98
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-c5e763bd300a> in <module>
#      13 verbose = False
#      14 train_acc_hist, val_acc_hist = train(model, X_train, y_train, X_val, y_val,
# ---> 15                   num_epoch=num_epoch, batch_size=batch_size, learning_rate=lr, verbose=verbose)
#      16 test(model, X_test, y_test)
#
# ~/utils/train_funcs.py in train(model, X_train, y_train, X_valid, y_valid, num_epoch, batch_size, learning_rate, learning_decay, optim, momentum, verbose)
#      35             y_batch = y_train[sample_idxs]
#      36             ## loss
# ---> 37             loss = model.loss(X_batch, y_batch)
#      38             # update model
#      39             if optim == 'SGD':
#
# ~/utils/classifiers/mlp.py in loss(self, X, y)
#      84         for i in range(1,num_layers):
#      85             da = relu_backward(dX, hidden_layers[num_layers-i-1])
# ---> 86             dX, dW, db = affine_backward(da, X, layers[num_layers-i-1].params[0], layers[num_layers-i-1].params[1])
#      87             #dW += self.reg * layers[num_layers-i-1].params[0]
#      88             layers[i].gradients = [dW, db]
#
# ~/utils/layer_funcs.py in affine_backward(dout, x, w, b)
#      57     #                   START OF YOUR CODE                                     #
#      58     ############################################################################
# ---> 59     dx = np.dot(dout, w.T).reshape(x.shape)
#      60     dw = np.dot(x.reshape(x.shape[0], np.prod(x.shape[1:])).T, dout)
#      61     db = np.sum(dout, axis=0)
#
# ValueError: cannot reshape array of size 50000 into shape (500,3072)

# %% [markdown]
# <p style='color:red'><strong>TODO:</strong></p>

# %%
# plot training and validation accuracy

# %% [markdown]
# <p style='color:red'><strong>SOLUTION (enter a new cell below):</strong></p>

# %%
plt.plot(train_acc_hist, label="train accuracy")
plt.plot(val_acc_hist, label="validation accuracy")
plt.legend()
plt.show()
